# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/mahme/Downloads/Data Analysis/PYHTON_VS_CODE/flights_sample_3m.csv')

# %%
df['FL_DATE'] = pd.to_datetime(df['FL_DATE'])

# %%
df['YEAR'] = df.FL_DATE.dt.year
df.YEAR
# Out:
# 0          2019
# 1          2022
# 2          2022
# 3          2023
# 4          2020
#            ...
# 2999995    2022
# 2999996    2022
# 2999997    2022
# 2999998    2019
# 2999999    2019
# Name: YEAR, Length: 3000000, dtype: int32

# %%
df
# Out:
#            FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# 0       2019-01-09   United Air Lines Inc.   United Air Lines Inc.: UA
# 1       2022-11-19    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 2       2022-07-22   United Air Lines Inc.   United Air Lines Inc.: UA
# 3       2023-03-06    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 4       2020-02-23        Spirit Air Lines        Spirit Air Lines: NK
# ...            ...                     ...                         ...
# 2999995 2022-11-13  American Airlines Inc.  American Airlines Inc.: AA
# 2999996 2022-11-02  American Airlines Inc.  American Airlines Inc.: AA
# 2999997 2022-09-11    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 2999998 2019-11-13        Republic Airline        Republic Airline: YX
# 2999999 2019-06-15  Southwest Airlines Co.  Southwest Airlines Co.: WN
#
#         AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY DEST  \
# ...

# %%
flights_data_2019 = df[df['YEAR'] == 2019]
flights_data_2019
# Out:
#            FL_DATE                 AIRLINE                 AIRLINE_DOT  \
# 0       2019-01-09   United Air Lines Inc.   United Air Lines Inc.: UA
# 5       2019-07-31  Southwest Airlines Co.  Southwest Airlines Co.: WN
# 7       2019-07-08        Republic Airline        Republic Airline: YX
# 13      2019-11-20    Delta Air Lines Inc.    Delta Air Lines Inc.: DL
# 18      2019-03-24        Spirit Air Lines        Spirit Air Lines: NK
# ...            ...                     ...                         ...
# 2999988 2019-04-16   SkyWest Airlines Inc.   SkyWest Airlines Inc.: OO
# 2999992 2019-01-13         JetBlue Airways         JetBlue Airways: B6
# 2999993 2019-12-23           Allegiant Air           Allegiant Air: G4
# 2999998 2019-11-13        Republic Airline        Republic Airline: YX
# 2999999 2019-06-15  Southwest Airlines Co.  Southwest Airlines Co.: WN
#
#         AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN             ORIGIN_CITY DEST  \
# ...

# %%
# flights_data_2019.to_csv('flights_data_2019.csv')

# %%
#  flights_data_2020 = df[df['YEAR'] == 2020]
#  flights_data_2020.to_csv('flights_data_2020.csv')

# %%
# flights_data_2021 = df[df['YEAR'] == 2021]
# flights_data_2021.to_csv('flights_data_2021.csv')

# %%
# flights_data_2022 = df[df['YEAR'] == 2022]
# flights_data_2022.to_csv('flights_data_2022.csv')

# %%
# flights_data_2023 = df[df['YEAR'] == 2023]
# flights_data_2023.to_csv('flights_data_2023.csv')
